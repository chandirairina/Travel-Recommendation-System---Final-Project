# %% [markdown]
# ### Scraping List of Asian Countries

# %%
import requests
import lxml.html as lh
import pandas as pd

# %%
url='https://en.wikipedia.org/wiki/List_of_Asian_countries_by_area'
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
[len(T) for T in tr_elements[1:12]]
# Out:
# [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4]

# %%
tr_elements=tr_elements[1:53]

# %%
#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print (i,name)
    col.append((name,[]))
# Out:
# 1 Rank
#
# 2 Country
#
# 3 Area (km²)
#
# 4 Notes

# %%
#Since out first row is the header, data is stored on the second row onwards
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 10, the //tr data is not from our table 
    if len(T)!=4:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %%
[len(C) for (title,C) in col]
# Out:
# [51, 51, 51, 51]

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)

# %%
df.head()
# Out:
#   Rank\n        Country\n  Area (km²)\n  \
# 0    1\n        Russia*\n  13,000,000\n
# 1    2\n          China\n   9,596,961\n
# 2    3\n          India\n   3,287,263\n
# 3    4\n    Kazakhstan*\n   2,544,900\n
# 4    5\n   Saudi Arabia\n   2,149,690\n
#
#                                              Notes\n
# 0      17,125,191 km² including European Russia[1]\n
# 1  excludes Hong Kong, Macau and other disputed a...
# 2                                                 \n
# 3            2,724,900 km² including European part\n
# 4                                                 \n

# %%
df.columns
# Out:
# Index(['Rank\n', 'Country\n', 'Area (km²)\n', 'Notes\n'], dtype='object')

# %%
df=df[['Country\n']]

# %%
df=df[:50]

# %%
df.rename(columns={'Country\n': "Country"}, inplace=True)

# %%
df
# Out:
#                     Country
# 0                 Russia*\n
# 1                   China\n
# 2                   India\n
# 3             Kazakhstan*\n
# 4            Saudi Arabia\n
# 5                    Iran\n
# 6                Mongolia\n
# 7              Indonesia*\n
# 8                Pakistan\n
# 9                 Turkey*\n
# 10                Myanmar\n
# 11            Afghanistan\n
# 12                  Yemen\n
# 13               Thailand\n
# 14           Turkmenistan\n
# 15             Uzbekistan\n
# 16                   Iraq\n
# 17                  Japan\n
# 18                Vietnam\n
# 19               Malaysia\n
# 20                   Oman\n
# 21            Philippines\n
# 22                   Laos\n
# 23             Kyrgyzstan\n
# 24                  Syria\n
# 25               Cambodia\n
# 26             Bangladesh\n
# 27                  Nepal\n
# 28             Tajikistan\n
# 29            North Korea\n
# 30            South Korea\n
# 31                 Jordan\n
# ...

# %%
df["Country"][0][-1:]
# Out:
# '\n'

# %%
df["Country"][0][0:-2]
# Out:
# '\xa0Russia'

# %% [markdown]
# omitting symbols and unneccessary string (*, \xa0 and \n)

# %%
def country(x):
    if x["Country"][-2]=="*":
        return x["Country"][0:-2]
    else:
        return x["Country"][0:-1]

# %%
df=df.apply(country,axis=1)

# %%
df=df.to_frame()

# %%
def country(x):
    if x["Country"][0]=="\xa0":
        return x["Country"][1:]

# %%
df=df.apply(country,axis=1)

# %%
df.to_frame()
# Out:
#                        0
# 0                 Russia
# 1                  China
# 2                  India
# 3             Kazakhstan
# 4           Saudi Arabia
# 5                   Iran
# 6               Mongolia
# 7              Indonesia
# 8               Pakistan
# 9                 Turkey
# 10               Myanmar
# 11           Afghanistan
# 12                 Yemen
# 13              Thailand
# 14          Turkmenistan
# 15            Uzbekistan
# 16                  Iraq
# 17                 Japan
# 18               Vietnam
# 19              Malaysia
# 20                  Oman
# 21           Philippines
# 22                  Laos
# 23            Kyrgyzstan
# 24                 Syria
# 25              Cambodia
# 26            Bangladesh
# 27                 Nepal
# 28            Tajikistan
# 29           North Korea
# 30           South Korea
# 31                Jordan
# 32            Azerbaijan
# 33  United Arab Emirates
# 34               Georgia
# 35             Sri Lanka
# ...

# %% [markdown]
# renaming the column

# %%
df.rename("Country", inplace=True)
# Out:
# 0                   Russia
# 1                    China
# 2                    India
# 3               Kazakhstan
# 4             Saudi Arabia
# 5                     Iran
# 6                 Mongolia
# 7                Indonesia
# 8                 Pakistan
# 9                   Turkey
# 10                 Myanmar
# 11             Afghanistan
# 12                   Yemen
# 13                Thailand
# 14            Turkmenistan
# 15              Uzbekistan
# 16                    Iraq
# 17                   Japan
# 18                 Vietnam
# 19                Malaysia
# 20                    Oman
# 21             Philippines
# 22                    Laos
# 23              Kyrgyzstan
# 24                   Syria
# 25                Cambodia
# 26              Bangladesh
# 27                   Nepal
# 28              Tajikistan
# 29             North Korea
# 30             South Korea
# 31                  Jordan
# 32              Azerbaijan
# 33    United Arab Emirates
# ...

# %%
df.to_frame()
# Out:
#                  Country
# 0                 Russia
# 1                  China
# 2                  India
# 3             Kazakhstan
# 4           Saudi Arabia
# 5                   Iran
# 6               Mongolia
# 7              Indonesia
# 8               Pakistan
# 9                 Turkey
# 10               Myanmar
# 11           Afghanistan
# 12                 Yemen
# 13              Thailand
# 14          Turkmenistan
# 15            Uzbekistan
# 16                  Iraq
# 17                 Japan
# 18               Vietnam
# 19              Malaysia
# 20                  Oman
# 21           Philippines
# 22                  Laos
# 23            Kyrgyzstan
# 24                 Syria
# 25              Cambodia
# 26            Bangladesh
# 27                 Nepal
# 28            Tajikistan
# 29           North Korea
# 30           South Korea
# 31                Jordan
# 32            Azerbaijan
# 33  United Arab Emirates
# 34               Georgia
# 35             Sri Lanka
# ...

# %%
df.to_csv("asiawiki.csv")
