# %%
import pandas as pd

# %%
df1=pd.read_csv("dataset_indo_engineered.csv")
df2=pd.read_csv("dataset_others_engineered.csv")

# %%
df1
# Out:
#     Country Name Travel Destination         Checking  \
# 0      Indonesia             Bintan           Bintan
# 1      Indonesia           Seminyak         Seminyak
# 2      Indonesia               Bali             Bali
# 3      Indonesia               Ubud             Ubud
# 4      Indonesia            Jakarta          Jakarta
# ..           ...                ...              ...
# 321    Indonesia          Toyapakeh        Toyapakeh
# 322    Indonesia         Singakerta       Singakerta
# 323    Indonesia             Guwang           Guwang
# 324    Indonesia    Singapadu Kaler  Singapadu Kaler
# 325    Indonesia         Batu Karas       Batu Karas
#
#                                           Things to Do  \
# 0    tur aktivitasluarruangan transportasi turdenga...
# 1    tur spadankebugaran aktivitasluarruangan tempa...
# 2    tur aktivitasluarruangan turdenganperahudanola...
# 3    tur aktivitasluarruangan spadankebugaran trans...
# ...

# %%
df2
# Out:
#      Travel Destination           Checking  \
# 0             Pasanauri          Pasanauri
# 1            Zeda Gordi         Zeda Gordi
# 2             Martivili          Martivili
# 3            Tsinandali         Tsinandali
# 4          Guria Region       Guria Region
# ...                 ...                ...
# 5290             Tawala             Tawala
# 5291  Negros Occidental  Negros Occidental
# 5292   Bulacan Province   Bulacan Province
# 5293       Bicol Region       Bicol Region
# 5294             Anilao             Anilao
#
#                                            Things to Do Country Name  \
# 0     tur turdenganperahudanolahragaair aktivitaslua...      Georgia
# 1     wisataalamdantaman cocokuntukpasangan hargater...      Georgia
# 2     pemandangandantengara wisataalamdantaman cocok...      Georgia
# 3     makanandanminuman museum pemandangandantengara...      Georgia
# 4     pemandangandantengara wisataalamdantaman aktiv...      Georgia
# ...

# %%
df_complete=pd.concat([df1,df2])

# %%
df_complete.to_csv("dataset_baseline.csv", index=False)
