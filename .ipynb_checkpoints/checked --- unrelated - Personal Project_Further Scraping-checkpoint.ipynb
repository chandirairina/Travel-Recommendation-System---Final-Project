# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep, strftime
from random import randint
import pandas as pd
import numpy as np

# %%
#for automating the chrome
chromedriver_path = r"C:\Users\chiri\Downloads\chromedriver.exe"

driver=webdriver.Chrome(executable_path=chromedriver_path)
# sleep(2)


#opening the website
driver.get("https://www.tripadvisor.co.id/")
sleep(3)

# %%
df=pd.read_csv("dataset_indo.csv")

# %%
df
# Out:
#      Unnamed: 0 Country Name Travel Destination         Checking  \
# 0             0    Indonesia             Bintan           Bintan
# 1             2    Indonesia           Seminyak         Seminyak
# 2             3    Indonesia               Bali             Bali
# 3             4    Indonesia               Ubud             Ubud
# 4             5    Indonesia            Jakarta          Jakarta
# ..          ...          ...                ...              ...
# 321         616    Indonesia          Toyapakeh        Toyapakeh
# 322         619    Indonesia         Singakerta       Singakerta
# 323         621    Indonesia             Guwang           Guwang
# 324         627    Indonesia    Singapadu Kaler  Singapadu Kaler
# 325         643    Indonesia         Batu Karas       Batu Karas
#
#                                           Things to Do  \
# 0    ['Tur (39)', 'Aktivitas Luar Ruangan (30)', 'T...
# 1    ['Tur (204)', 'Spa & Kebugaran (164)', 'Aktivi...
# ...

# %%
wisata=df["Travel Destination"].values

# %%
wisata[0]
# Out:
# 'Bintan'

# %%
destination=[]
activity=[]
spot=[]
link=[]
review=[]
star=[]

#melakukan looping berikut ini untuk semua destinasi wisata di indonesia yang sudah dicleaning
for tempat in wisata[0:2]:
    #menampung data destinasi wisata
    print(tempat)
    destination.append(tempat)
    
    #opening the website and navigation to the intended page
    try:
        driver.get("https://www.tripadvisor.co.id/")
        sleep(3)
    except:
        try:
            driver.get("https://www.tripadvisor.co.id/")
            sleep(5)
        except:
            driver.get("https://www.tripadvisor.co.id/")
            sleep(5)
            
    todo=driver.find_element_by_xpath('//*[@id="lithium-root"]/main/div[1]/div[1]/div/div/div[2]/a/span/span[1]')
    todo.click()
    sleep(2)

    searchtodo=driver.find_element_by_css_selector('body > div._5_xsoLU2 > div > form > input._3qLQ-U8m')
    searchtodo.send_keys(tempat)
    sleep(2)
    searchtodo.send_keys(Keys.ENTER)
    sleep(2)
    
    try:
        types=driver.find_elements_by_class_name("_3S09qsQh._30GXgBoj")
        jeniss=[]
        #cek ada aktivitas apa saja yang dapat dilakukan di destinasi tersebut dan menyimpannya secara temporer
        for jenis in types:    
            if jenis.text!="":
                jeniss.append(jenis.text)
            
        print(jeniss)
        sleep(3)   
    except:
        jeniss.append(np.nan)
        
    #melakukan looping untuk tiap jenis aktivitas di destinasi tersebut.
    for l in range(1,20):
        for k in range(1,20):
            for i in range(1,3):
                for j in range(len(jeniss)+1)[1:]:
                    try:                          
                        print(driver.find_element_by_xpath(f'//*[@id="lithium-root"]/main/div[{l}]/div/div/div/div[{k}]/div[{i}]/span[{j}]/a').text)
                        driver.find_element_by_xpath(f'//*[@id="lithium-root"]/main/div[{l}]/div/div/div/div[{k}]/div[{i}]/span[{j}]/a').click()
                        sleep(3)

                        #menampung data untuk kolom jenis aktivitas
                        activity.append(jeniss[j-1])
                        print(jeniss[j-1])

                        #mengarahkan page ke halaman yang diinginkan
                        print(i,j)
                        
                        #looping untuk setiap halaman di page aktivitas yang spesifik dan mengambil data-datanya
                        for page in range(0,100):

                            lists = driver.find_elements_by_class_name("_1MKm6PFo")
                            for elem in lists[1:]:

                                print(page)

                                #mengambil data spot
                                try:
                                    spot.append(elem.find_element_by_class_name('_1QKQOve4').text)
                                    print(elem.find_element_by_class_name('_1QKQOve4').text)
                                except:
                                    spot.append(np.nan)
                                    print(np.nan)

                                #mengambil data link spot
                                try:
                                    link.append(elem.find_element_by_class_name('_1QKQOve4').get_attribute("href"))
                                    print(elem.find_element_by_class_name('_1QKQOve4').get_attribute("href"))
                                except:
                                    link.append(np.nan)
                                    print(np.nan)

                                #mengambil data jumlah review
                                try:
                                    review.append(elem.find_element_by_class_name('HLvj7Lh5._1L-8ZIjh._2s3pPhGm').text)
                                    print(elem.find_element_by_class_name('HLvj7Lh5._1L-8ZIjh._2s3pPhGm').text)
                                except:
                                    review.append(np.nan)
                                    print(np.nan)

                                #mengambil data jumlah bintang/star/rating
                                try:
                                    star.append(elem.find_element_by_class_name('_3KcXyP0F.wxkjkcMP._1DZZGRFQ').get_attribute("title"))
                                    print(elem.find_element_by_class_name('_3KcXyP0F.wxkjkcMP._1DZZGRFQ').get_attribute("title"))
                                except:
                                    star.append(np.nan)
                                    print(np.nan)
                                sleep(2)

                                try:
                                    next_button=driver.find_element_by_class_name('ui_button.nav.next.primary')
                                    next_button.click()
                                    sleep(2)
                                except:
                                    break
                        
                        back=driver.find_element_by_xpath('//*[@id="component_9"]/div/div/div/div/ul/li[1]/div/div/a/span')
                        back.click()
                        sleep(2)


                            
                       
    #             driver.find_elements_by_class_name("_1MKm6PFo")[1].find_element_by_class_name('_1QKQOve4').text
    #             driver.find_elements_by_class_name("_1MKm6PFo")[1].find_element_by_class_name('HLvj7Lh5._1L-8ZIjh._2s3pPhGm').text
    #             driver.find_elements_by_class_name("_1MKm6PFo")[1].find_element_by_class_name('_3KcXyP0F.wxkjkcMP._1DZZGRFQ').get_attribute("title")
          
#                 //*[@id="component_9"]/div/div/div/div/ul/li[1]/div/div/a/span
#                 driver.get("https://www.tripadvisor.co.id/")
#                 sleep(2)
                    except:
                        break
    
                    



# coba=driver.find_elements_by_class_name("_3S09qsQh._30GXgBoj")

# types=[]
# for i in coba:
#     if (i.text!="") & (i.text!="See all"):
#         types.append(i.text)
# print(types)
# //*[@id="lithium-root"]/main/div[5]/div/div/div/div[13]/div[1]/span[1]/a
# //*[@id="lithium-root"]/main/div[5]/div/div/div/div[13]/div[1]/span[2]/a
# //*[@id="lithium-root"]/main/div[5]/div/div/div/div[13]/div[1]/span[12]
# //*[@id="lithium-root"]/main/div[5]/div/div/div/div[13]/div[2]/span[10]/a

# for i in range(1,3):
#     for j in range(len(types)+1)[1:]:
#         try:
#             print(driver.find_element_by_xpath(f'//*[@id="lithium-root"]/main/div[5]/div/div/div/div[13]/div[{i}]/span[{j}]/a').text)
#             driver.find_element_by_xpath(f'//*[@id="lithium-root"]/main/div[5]/div/div/div/div[13]/div[{i}]/span[{j}]/a').click()
            
#             driver.find_elements_by_class_name("_1MKm6PFo")[1].find_element_by_class_name('_1QKQOve4').text
#             driver.find_elements_by_class_name("_1MKm6PFo")[1].find_element_by_class_name('HLvj7Lh5._1L-8ZIjh._2s3pPhGm').text
#             driver.find_elements_by_class_name("_1MKm6PFo")[1].find_element_by_class_name('_3KcXyP0F.wxkjkcMP._1DZZGRFQ').get_attribute("title")

#             driver.get("https://www.tripadvisor.com/Attractions-g664666-Activities-Gili_Trawangan_Gili_Islands_Pemenang_Lombok_West_Nusa_Tenggara.html")
#             sleep(2)
#         except:
#             break
# Out:
# Bintan
# ['Tur (39)', 'Aktivitas Luar Ruangan (30)', 'Transportasi (21)', 'Tur dengan Perahu & Olahraga Air (20)', 'Pemandangan & Tengara (16)', 'Spa & Kebugaran (11)', 'Wisata Alam & Taman (9)', 'Hiburan malam (6)', 'Tempat Belanja (4)', 'Kebun Binatang & Akuarium (2)', 'Makanan & Minuman (1)', 'Kursus & Sanggar (1)', 'Taman Air & Taman Hiburan (1)', 'Hiburan & Permainan (1)', 'Sumber Informasi Wisatawan (1)', 'Cocok untuk Pasangan (16)', 'Harga terjangkau (15)', 'Cocok untuk Anak-Anak (14)', 'Cocok untuk Kelompok Besar (13)', 'Masuk Gratis (12)', 'Bagus Saat Hujan (10)', 'Lokasi bulan madu (5)', 'Cocok untuk Penggemar Aktivitas Ekstrem (3)', 'Tempat yang Belum Populer (3)', 'Berjiwa petualang (2)']
# Tur (39)
# Tur (39)
# 1 1
# 0
# Bintan Trip
# https://www.tripadvisor.co.id/Attraction_Review-g297718-d15694195-Reviews-Bintan_Trip-Bintan_Island_Bintan_Regency_Riau_Archipelago_Riau_Islands_Province.html
# 36 ulasan
# 5,0 dari 5 lingkaran
# 0
# Bintan Taxi (民丹岛出租车服务）
# ...

# %%
driver.get("https://www.tripadvisor.co.id/Attractions-g12811408-Activities-Bintan_Regency_Riau_Archipelago_Riau_Islands_Province.html")
sleep(3)

coba=driver.find_elements_by_class_name("_3S09qsQh._30GXgBoj")

types=[]
for i in coba:
    if (i.text!="") & (i.text!="See all"):
        types.append(i.text)
print(types)

for l in range(0,20):
    for k in range(0,20):
        for i in range(1,3):
            for j in range(len(types)+1)[1:]:
                try:
                    print(driver.find_element_by_xpath(f'//*[@id="lithium-root"]/main/div[{l}]/div/div/div/div[{k}]/div[{i}]/span[{j}]/a').text)
                    driver.find_element_by_xpath(f'//*[@id="lithium-root"]/main/div[{l}]/div/div/div/div[{k}]/div[{i}]/span[{j}]/a').click()
                    sleep(2)

                    lists = driver.find_elements_by_class_name("_1MKm6PFo")
                    for page in range(1,50):
                        for elem in lists[1:]:
                            try:
                                spot.append(elem.find_element_by_class_name('_1QKQOve4').text)
                                print(elem.find_element_by_class_name('_1QKQOve4').text)
                            except:
                                spot.append(np.nan)
                                print(np.nan)

                            #mengambil data link spot
                            try:
                                link.append(elem.find_element_by_class_name('_1QKQOve4').get_attribute("href"))
                                print(elem.find_element_by_class_name('_1QKQOve4').get_attribute("href"))
                            except:
                                link.append(np.nan)
                                print(np.nan)

                            #mengambil data jumlah review
                            try:
                                review.append(elem.find_element_by_class_name('HLvj7Lh5._1L-8ZIjh._2s3pPhGm').text)
                                print(elem.find_element_by_class_name('HLvj7Lh5._1L-8ZIjh._2s3pPhGm').text)
                            except:
                                review.append(np.nan)
                                print(np.nan)

                            #mengambil data jumlah bintang/star/rating
                            try:
                                star.append(elem.find_element_by_class_name('_3KcXyP0F.wxkjkcMP._1DZZGRFQ').get_attribute("title"))
                                print(elem.find_element_by_class_name('_3KcXyP0F.wxkjkcMP._1DZZGRFQ').get_attribute("title"))
                            except:
                                star.append(np.nan)
                                print(np.nan)
                            sleep(2)
                            
                        try:
                            next_button=driver.find_element_by_class_name('ui_button.nav.next.primary')
                            next_button.click()
                            sleep(2)
                        except:
                            break

#                     back=driver.find_element_by_xpath('//*[@id="component_9"]/div/div/div/div/ul/li[1]/div/div/a')
#                     back.click()
#                     sleep(2)
                except:
                    break
# Out:
# ['Tur (40)', 'Aktivitas Luar Ruangan (31)', 'Transportasi (23)', 'Tur dengan Perahu & Olahraga Air (21)', 'Pemandangan & Tengara (16)', 'Spa & Kebugaran (11)', 'Wisata Alam & Taman (9)', 'Hiburan malam (6)', 'Tempat Belanja (4)', 'Kebun Binatang & Akuarium (2)', 'Makanan & Minuman (1)', 'Kursus & Sanggar (1)', 'Museum (1)', 'Taman Air & Taman Hiburan (1)', 'Hiburan & Permainan (1)', 'Lihat semua', 'Cocok untuk Pasangan (16)', 'Harga terjangkau (15)', 'Cocok untuk Anak-Anak (14)', 'Cocok untuk Kelompok Besar (13)', 'Masuk Gratis (12)', 'Bagus Saat Hujan (10)', 'Lokasi bulan madu (5)', 'Cocok untuk Penggemar Aktivitas Ekstrem (3)', 'Tempat yang Belum Populer (3)', 'Berjiwa petualang (2)']
# Tur (40)

# %%
driver.get("https://www.tripadvisor.co.id/Attractions-g12811408-Activities-Bintan_Regency_Riau_Archipelago_Riau_Islands_Province.html")
sleep(3)

coba=driver.find_elements_by_class_name("_3S09qsQh._30GXgBoj")

types=[]
for i in coba:
    if (i.text!="") & (i.text!="See all"):
        types.append(i.text)
print(types)

for l in range(0,20):
    for k in range(0,20):
        for i in range(1,3):
            for j in range(len(types)+1)[1:]:
                try:
                    print(driver.find_element_by_xpath(f'//*[@id="lithium-root"]/main/div[{l}]/div/div/div/div[{k}]/div[{i}]/span[{j}]/a').text)
                    driver.find_element_by_xpath(f'//*[@id="lithium-root"]/main/div[{l}]/div/div/div/div[{k}]/div[{i}]/span[{j}]/a').click()
                    sleep(2)
# //*[@id="lithium-root"]/main/div[5]/div/div/div/div[5]/div[1]/span[8]/a
                    lists = driver.find_elements_by_class_name("_1MKm6PFo")
                    for elem in lists[1:]:
                        try:
                            spot.append(elem.find_element_by_class_name('_1QKQOve4').text)
                            print(elem.find_element_by_class_name('_1QKQOve4').text)
                        except:
                            spot.append(np.nan)
                            print(np.nan)

                        #mengambil data link spot
                        try:
                            link.append(elem.find_element_by_class_name('_1QKQOve4').get_attribute("href"))
                            print(elem.find_element_by_class_name('_1QKQOve4').get_attribute("href"))
                        except:
                            link.append(np.nan)
                            print(np.nan)

                        #mengambil data jumlah review
                        try:
                            review.append(elem.find_element_by_class_name('HLvj7Lh5._1L-8ZIjh._2s3pPhGm').text)
                            print(elem.find_element_by_class_name('HLvj7Lh5._1L-8ZIjh._2s3pPhGm').text)
                        except:
                            review.append(np.nan)
                            print(np.nan)

                        #mengambil data jumlah bintang/star/rating
                        try:
                            star.append(elem.find_element_by_class_name('_3KcXyP0F.wxkjkcMP._1DZZGRFQ').get_attribute("title"))
                            print(elem.find_element_by_class_name('_3KcXyP0F.wxkjkcMP._1DZZGRFQ').get_attribute("title"))
                        except:
                            star.append(np.nan)
                            print(np.nan)
                        sleep(2)

                    back=driver.find_element_by_xpath('//*[@id="component_9"]/div/div/div/div/ul/li[1]/div/div/a')
                    back.click()
                    sleep(2)
                except:
                    break
# Out:
# ['Tur (40)', 'Aktivitas Luar Ruangan (31)', 'Transportasi (23)', 'Tur dengan Perahu & Olahraga Air (21)', 'Pemandangan & Tengara (16)', 'Spa & Kebugaran (11)', 'Wisata Alam & Taman (9)', 'Hiburan malam (6)', 'Tempat Belanja (4)', 'Kebun Binatang & Akuarium (2)', 'Makanan & Minuman (1)', 'Kursus & Sanggar (1)', 'Museum (1)', 'Taman Air & Taman Hiburan (1)', 'Hiburan & Permainan (1)', 'Lihat semua', 'Cocok untuk Pasangan (16)', 'Harga terjangkau (15)', 'Cocok untuk Anak-Anak (14)', 'Cocok untuk Kelompok Besar (13)', 'Masuk Gratis (12)', 'Bagus Saat Hujan (10)', 'Lokasi bulan madu (5)', 'Cocok untuk Penggemar Aktivitas Ekstrem (3)', 'Tempat yang Belum Populer (3)', 'Berjiwa petualang (2)']
# Tur (40)

# %%
print(len(destination))
print(len(activity))
print(len(spot))
print(len(link))
print(len(review))
print(len(star))
# Out:
# 2
# 9
# 257
# 257
# 257
# 257

# %%
driver.get("https://www.tripadvisor.co.id/Attractions-g12811408-Activities-Bintan_Regency_Riau_Archipelago_Riau_Islands_Province.html")
sleep(3)

coba=driver.find_elements_by_class_name("_3S09qsQh._30GXgBoj")

types=[]
for i in coba:
    if (i.text!="") & (i.text!="See all"):
        types.append(i.text)
print(types)
# //*[@id="lithium-root"]/main/div[5]/div/div/div/div[13]/div[1]/span[1]/a
# //*[@id="lithium-root"]/main/div[5]/div/div/div/div[13]/div[1]/span[2]/a
# //*[@id="lithium-root"]/main/div[5]/div/div/div/div[13]/div[1]/span[12]
# //*[@id="lithium-root"]/main/div[5]/div/div/div/div[13]/div[2]/span[10]/a

for l in range(0,20):
    for k in range(0,20):
        for i in range(1,3):
            for j in range(len(types)+1)[1:]:

                try:
#                     if (driver.find_element_by_xpath(f'//*[@id="lithium-root"]/main/div[{l}]/div/div/div/div[{k}]/div[{i}]/span[{j}]/a').text)==(types[j-1]):
                        print(driver.find_element_by_xpath(f'//*[@id="lithium-root"]/main/div[{l}]/div/div/div/div[{k}]/div[{i}]/span[{j}]/a').text)
                        driver.find_element_by_xpath(f'//*[@id="lithium-root"]/main/div[{l}]/div/div/div/div[{k}]/div[{i}]/span[{j}]/a').click()
        # //*[@id="lithium-root"]/main/div[3]/div/div/div/div[4]/div[1]/span[1]/a
        # //*[@id="lithium-root"]/main/div[3]/div/div/div/div[3]/div[1]/span[1]/a
                        sleep(2)
                        
                        print(driver.find_elements_by_class_name("_1MKm6PFo")[0].find_element_by_class_name('_1QKQOve4').text)
#                         driver.find_elements_by_class_name("_1MKm6PFo")[1].find_element_by_class_name('HLvj7Lh5._1L-8ZIjh._2s3pPhGm').text
#                         driver.find_elements_by_class_name("_1MKm6PFo")[1].find_element_by_class_name('_3KcXyP0F.wxkjkcMP._1DZZGRFQ').get_attribute("title")

                        driver.get("https://www.tripadvisor.co.id/Attractions-g12811408-Activities-Bintan_Regency_Riau_Archipelago_Riau_Islands_Province.html")
                        sleep(2)
                except:
                    break
# Out:
# ['Tur (40)', 'Aktivitas Luar Ruangan (31)', 'Transportasi (23)', 'Tur dengan Perahu & Olahraga Air (21)', 'Pemandangan & Tengara (16)', 'Spa & Kebugaran (11)', 'Wisata Alam & Taman (9)', 'Hiburan malam (6)', 'Tempat Belanja (4)', 'Kebun Binatang & Akuarium (2)', 'Makanan & Minuman (1)', 'Kursus & Sanggar (1)', 'Museum (1)', 'Taman Air & Taman Hiburan (1)', 'Hiburan & Permainan (1)', 'Lihat semua', 'Cocok untuk Pasangan (16)', 'Harga terjangkau (15)', 'Cocok untuk Anak-Anak (14)', 'Cocok untuk Kelompok Besar (13)', 'Masuk Gratis (12)', 'Bagus Saat Hujan (10)', 'Lokasi bulan madu (5)', 'Cocok untuk Penggemar Aktivitas Ekstrem (3)', 'Tempat yang Belum Populer (3)', 'Berjiwa petualang (2)']
# Tur (40)
# Air Adventures Flying Club Bintan
# Aktivitas Luar Ruangan (31)
# Klub Golf Ria Bintan
# Transportasi (23)
# Bintan Taxi
# Tur dengan Perahu & Olahraga Air (21)
# Bintan Taxi (民丹岛出租车服务）
# Pemandangan & Tengara (16)
# 500 Lohan Temple
# Spa & Kebugaran (11)
# Spa Angsana Bintan
# ...

# %%
driver.get("https://www.tripadvisor.co.id/Attractions-g12811408-Activities-Bintan_Regency_Riau_Archipelago_Riau_Islands_Province.html")
sleep(3)

coba=driver.find_elements_by_class_name("_3S09qsQh._30GXgBoj")

types=[]
for i in coba:
    if (i.text!="") & (i.text!="See all"):
        types.append(i.text)
print(types)
# //*[@id="lithium-root"]/main/div[5]/div/div/div/div[13]/div[1]/span[1]/a
# //*[@id="lithium-root"]/main/div[5]/div/div/div/div[13]/div[1]/span[2]/a
# //*[@id="lithium-root"]/main/div[5]/div/div/div/div[13]/div[1]/span[12]
# //*[@id="lithium-root"]/main/div[5]/div/div/div/div[13]/div[2]/span[10]/a

for l in range(0,20):
    for k in range(0,20):
        for i in range(1,3):
            for j in range(len(types)+1)[1:]:

                try:
#                     if (driver.find_element_by_xpath(f'//*[@id="lithium-root"]/main/div[{l}]/div/div/div/div[{k}]/div[{i}]/span[{j}]/a').text)==(types[j-1]):
                        print(driver.find_element_by_xpath(f'//*[@id="lithium-root"]/main/div[{l}]/div/div/div/div[{k}]/div[{i}]/span[{j}]/a').text)
                        driver.find_element_by_xpath(f'//*[@id="lithium-root"]/main/div[{l}]/div/div/div/div[{k}]/div[{i}]/span[{j}]/a').click()
        # //*[@id="lithium-root"]/main/div[3]/div/div/div/div[4]/div[1]/span[1]/a
        # //*[@id="lithium-root"]/main/div[3]/div/div/div/div[3]/div[1]/span[1]/a
                        sleep(2)
                        print(driver.find_elements_by_class_name("_1MKm6PFo")[0].find_element_by_class_name('_1QKQOve4').text)
#                         driver.find_elements_by_class_name("_1MKm6PFo")[1].find_element_by_class_name('HLvj7Lh5._1L-8ZIjh._2s3pPhGm').text
#                         driver.find_elements_by_class_name("_1MKm6PFo")[1].find_element_by_class_name('_3KcXyP0F.wxkjkcMP._1DZZGRFQ').get_attribute("title")

                        back=driver.find_element_by_xpath('//*[@id="component_9"]/div/div/div/div/ul/li[1]/div/div/a/span')
                        back.click()
                        sleep(2)
                except:
                    break
# Out:
# ['Tur (40)', 'Aktivitas Luar Ruangan (31)', 'Transportasi (23)', 'Tur dengan Perahu & Olahraga Air (21)', 'Pemandangan & Tengara (16)', 'Spa & Kebugaran (11)', 'Wisata Alam & Taman (9)', 'Hiburan malam (6)', 'Tempat Belanja (4)', 'Kebun Binatang & Akuarium (2)', 'Makanan & Minuman (1)', 'Kursus & Sanggar (1)', 'Museum (1)', 'Taman Air & Taman Hiburan (1)', 'Hiburan & Permainan (1)', 'Lihat semua', 'Cocok untuk Pasangan (16)', 'Harga terjangkau (15)', 'Cocok untuk Anak-Anak (14)', 'Cocok untuk Kelompok Besar (13)', 'Masuk Gratis (12)', 'Bagus Saat Hujan (10)', 'Lokasi bulan madu (5)', 'Cocok untuk Penggemar Aktivitas Ekstrem (3)', 'Tempat yang Belum Populer (3)', 'Berjiwa petualang (2)']
# Tur (40)
# Air Adventures Flying Club Bintan
# Aktivitas Luar Ruangan (31)
# Klub Golf Ria Bintan
# Transportasi (23)
# Bintan Taxi
# Tur dengan Perahu & Olahraga Air (21)
# Bintan Taxi (民丹岛出租车服务）
# Pemandangan & Tengara (16)
# 500 Lohan Temple
# Spa & Kebugaran (11)
# Spa Angsana Bintan
# ...

# %%
lists=driver.find_elements_by_class_name("_1MKm6PFo")

# %%
lists
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="63a23db380234514ab82cda914a89415", element="832f873b-8c2c-42f9-86a9-5f72c13c7217")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="63a23db380234514ab82cda914a89415", element="87bf79d5-3e0e-479f-9262-fc1b118ba134")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="63a23db380234514ab82cda914a89415", element="f3cf0218-dbfd-4176-9128-879da15faca2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="63a23db380234514ab82cda914a89415", element="c4db2189-84ac-49b3-8c76-45e4af315efd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="63a23db380234514ab82cda914a89415", element="e093d75e-ade3-4873-8a58-93bf1753fc78")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="63a23db380234514ab82cda914a89415", element="88853107-398d-45be-9673-c8203bc3797e")>,
# ...

# %%
driver.find_elements_by_class_name("_1MKm6PFo")[1].find_element_by_class_name('_1QKQOve4').text
# Out:
# 'Bintan Trip'

# %%
driver.find_elements_by_class_name("_1MKm6PFo")[1].find_element_by_class_name('_1QKQOve4').get_attribute("href")
# Out:
# 'https://www.tripadvisor.co.id/Attraction_Review-g297718-d10686352-Reviews-Bintan_T3-Bintan_Island_Bintan_Regency_Riau_Archipelago_Riau_Islands_Province.html'

# %%
driver.find_elements_by_class_name("_1MKm6PFo")[1].find_element_by_class_name('HLvj7Lh5._1L-8ZIjh._2s3pPhGm').text
# _3KcXyP0F wxkjkcMP _1DZZGRFQ _1QKQOve4
# HLvj7Lh5 _1L-8ZIjh _2s3pPhGm
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-37-67a342dce2ac> in <module>
# ----> 1 driver.find_elements_by_class_name("_1MKm6PFo")[1].find_element_by_class_name('HLvj7Lh5._1L-8ZIjh._2s3pPhGm').text
#       2 # _3KcXyP0F wxkjkcMP _1DZZGRFQ _1QKQOve4
#       3 # HLvj7Lh5 _1L-8ZIjh _2s3pPhGm
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element_by_class_name(self, name)
#     396             element = element.find_element_by_class_name('foo')
#     397         """
# --> 398         return self.find_element(by=By.CLASS_NAME, value=name)
#     399
#     400     def find_elements_by_class_name(self, name):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element(self, by, value)
#     657
#     658         return self._execute(Command.FIND_CHILD_ELEMENT,
# ...

# %%
driver.find_elements_by_class_name("_1MKm6PFo")[1].find_element_by_class_name('_3KcXyP0F.wxkjkcMP._1DZZGRFQ').get_attribute("title")
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-39-5f9fab1b316a> in <module>
# ----> 1 driver.find_elements_by_class_name("_1MKm6PFo")[1].find_element_by_class_name('_3KcXyP0F.wxkjkcMP._1DZZGRFQ').get_attribute("title")
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element_by_class_name(self, name)
#     396             element = element.find_element_by_class_name('foo')
#     397         """
# --> 398         return self.find_element(by=By.CLASS_NAME, value=name)
#     399
#     400     def find_elements_by_class_name(self, name):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element(self, by, value)
#     657
#     658         return self._execute(Command.FIND_CHILD_ELEMENT,
# --> 659                              {"using": by, "value": value})['value']
#     660
# ...

# %%
link=driver.find_elements_by_class_name("_1MKm6PFo")

for page in range(1,10):
    for i in link:
        print(i.text)
        print(i.get_attribute("href"))
    
    try:
        next_button=driver.find_element_by_class_name('ui_button.nav.next.primary')
        next_button.click()
        sleep(2)

    except:
        break
# Out:
# Air Adventures Flying Club Bintan
# 64 ulasan
# No. 1 dari 40 Tur di Bintan Regency
# Pelajari Selengkapnya
# None
# Bintan Trip
# 36 ulasan
# No. 2 dari 40 Tur di Bintan Regency
# Pelajari Selengkapnya
# None
# Bintan Taxi (民丹岛出租车服务）
# 32 ulasan
# No. 3 dari 40 Tur di Bintan Regency
# Pelajari Selengkapnya
# Lihat 8 Pengalaman
# None
# Bintan taxi adventure
# 4 ulasan
# No. 4 dari 40 Tur di Bintan Regency
# Pelajari Selengkapnya
# None
# Bintan Adventures
# 26 ulasan
# No. 5 dari 40 Tur di Bintan Regency
# Pelajari Selengkapnya
# None
# Tanah Laut Adventures
# 23 ulasan
# No. 6 dari 40 Tur di Bintan Regency
# Pelajari Selengkapnya
# None
# BindoTravel
# 1 ulasan
# No. 7 dari 40 Tur di Bintan Regency
# Pelajari Selengkapnya
# Lihat 1 Pengalaman
# None
# Bintan Mangrove Discovery - Tur Harian
# 62 ulasan
# No. 8 dari 40 Tur di Bintan Regency
# Pelajari Selengkapnya
# None
# Bintan Piknik
# 11 ulasan
# No. 9 dari 40 Tur di Bintan Regency
# Pelajari Selengkapnya
# Lihat 2 Pengalaman
# ...

# %%
link=driver.find_elements_by_class_name("_1QKQOve4")

for page in range(1,10):
    for i in link:
        print(i.text)
        print(i.get_attribute("href"))
        
    
    try:
        next_button=driver.find_element_by_class_name('ui_button.nav.next.primary')
        next_button.click()
        sleep(2)

    except:
        break
# Out:
# Bintan Divers
# https://www.tripadvisor.co.id/Attraction_Review-g3223519-d12202999-Reviews-Bintan_Divers-Telukbakau_Bintan_Island_Bintan_Regency_Riau_Archipelago_Riau_Isl.html
# Bintan T3
# https://www.tripadvisor.co.id/Attraction_Review-g297718-d10686352-Reviews-Bintan_T3-Bintan_Island_Bintan_Regency_Riau_Archipelago_Riau_Islands_Province.html
# Bintan Holiday
# https://www.tripadvisor.co.id/Attraction_Review-g303959-d20995037-Reviews-Bintan_Holiday-Tanjung_Pinang_Bintan_Island_Bintan_Regency_Riau_Archipelago_Riau.html
# Babalovetrip
# https://www.tripadvisor.co.id/Attraction_Review-g297718-d20821729-Reviews-Babalovetrip-Bintan_Island_Bintan_Regency_Riau_Archipelago_Riau_Islands_Province.html
# Langlang Laut Sakti
# https://www.tripadvisor.co.id/Attraction_Review-g303959-d19458788-Reviews-Langlang_Laut_Sakti-Tanjung_Pinang_Bintan_Island_Bintan_Regency_Riau_Archipelago.html
# Travel Tours & Rent Cars Bintan
# ...

# %%
len(types)
# Out:
# 22
