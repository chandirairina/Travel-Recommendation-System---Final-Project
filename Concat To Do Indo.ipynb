# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv("dataset_tahap2.csv")
df2=pd.read_csv("dataset_tahap2_1.csv")
df3=pd.read_csv("dataset_tahap2_2.csv")
df4=pd.read_csv("dataset_tahap2_3.csv")
df5=pd.read_csv("dataset_tahap2_4.csv")

# %%
df=pd.concat([df1,df2,df3,df4,df5])

# %%
df
# Out:
#           destiny                                  todo  \
# 0          Bintan                              Tur (39)
# 1          Bintan                              Tur (39)
# 2          Bintan                              Tur (39)
# 3          Bintan                              Tur (39)
# 4          Bintan                              Tur (39)
# ...           ...                                   ...
# 25761  Batu Karas                               Tur (2)
# 25762  Batu Karas  Tur dengan Perahu & Olahraga Air (2)
# 25763  Batu Karas  Tur dengan Perahu & Olahraga Air (2)
# 25764  Batu Karas            Aktivitas Luar Ruangan (2)
# 25765  Batu Karas            Aktivitas Luar Ruangan (2)
#
#                                todo_lagi                rating  reviewers  \
# 0      Air Adventures Flying Club Bintan  5,0 dari 5 lingkaran  64 ulasan
# 1                            Bintan Trip  5,0 dari 5 lingkaran  36 ulasan
# ...

# %% [markdown]
# omitting data without rating

# %%
df[df["rating"].isnull()]
# Out:
#                destiny                                  todo  \
# 7               Bintan                              Tur (39)
# 9               Bintan                              Tur (39)
# 14              Bintan                              Tur (39)
# 15              Bintan                              Tur (39)
# 17              Bintan                              Tur (39)
# ...                ...                                   ...
# 25753       Singakerta                  Kursus & Sanggar (1)
# 25754       Singakerta               Hiburan & Permainan (1)
# 25757  Singapadu Kaler                               Tur (1)
# 25758  Singapadu Kaler  Tur dengan Perahu & Olahraga Air (1)
# 25759  Singapadu Kaler            Aktivitas Luar Ruangan (1)
#
#                                     todo_lagi rating  reviewers  \
# 7      Bintan Mangrove Discovery - Tur Harian    NaN  62 ulasan
# 9            Chill Cove @ Treasure Bay Bintan    NaN  60 ulasan
# ...

# %%
df.to_csv("dataset_spot_indo.csv", index=False)

# %% [markdown]
# check and drop for any duplications

# %%
df[df.duplicated()]
# Out:
#             destiny                           todo  \
# 974          Bintan                       Tur (39)
# 975          Bintan                       Tur (39)
# 976          Bintan                       Tur (39)
# 977          Bintan                       Tur (39)
# 978          Bintan                       Tur (39)
# ...             ...                            ...
# 61465  Kuta Selatan               Masuk Gratis (9)
# 61466  Kuta Selatan               Masuk Gratis (9)
# 61467  Kuta Selatan               Masuk Gratis (9)
# 61468  Kuta Selatan  Tempat yang Belum Populer (4)
# 61469  Kuta Selatan  Tempat yang Belum Populer (4)
#
#                                todo_lagi  reviewers  \
# 974    Air Adventures Flying Club Bintan         64
# 975                          Bintan Trip         36
# 976               Bintan Taxi (民丹岛出租车服务）         32
# 977                Bintan taxi adventure          4
# 978                    Bintan Adventures         26
# ...

# %%
df=df.drop_duplicates(keep="first")

# %%
df=df.reset_index().drop("index", axis=1)

# %%
df.to_csv("dataset_spot_indo.csv")
